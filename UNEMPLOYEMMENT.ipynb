# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/sample_data/unemployment.csv')
data.head()
# Out:
#                   Country Name Country Code   1991   1992   1993   1994  \
# 0  Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                  Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2   Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                       Angola          AGO   4.21   4.21   4.23   4.16
# 4                      Albania          ALB  10.31  30.01  25.26  20.84
#
#     1995   1996   1997   1998  ...   2012   2013   2014   2015   2016   2017  \
# 0   7.83   7.84   7.86   7.81  ...   6.56   6.45   6.41   6.49   6.61   6.71
# 1  11.18  10.96  10.78  10.80  ...  11.34  11.19  11.14  11.13  11.16  11.18
# 2   4.53   4.57   4.60   4.66  ...   4.64   4.41   4.69   4.63   5.57   6.02
# 3   4.11   4.10   4.09   4.07  ...   7.35   7.37   7.37   7.39   7.41   7.41
# 4  14.61  13.93  16.88  20.05  ...  13.38  15.87  18.05  17.19  15.42  13.62
#
#     2018   2019   2020   2021
# 0   6.73   6.91   7.56   8.11
# ...

# %%
old_name = ['Country Name']
new_name = ['Year']
data.rename(columns=dict(zip(old_name, new_name)), inplace=True)

# %%
#data.head()

# %%
data.shape
# Out:
# (235, 33)

# %%
data.set_index('Year', inplace=True)
data.drop('Country Code', inplace=True, axis=1)
data = data.transpose()

# %%
data.head()
# Out:
# Year  Africa Eastern and Southern  Afghanistan  Africa Western and Central  \
# 1991                         7.80        10.65                        4.42
# 1992                         7.84        10.82                        4.53
# 1993                         7.85        10.72                        4.55
# 1994                         7.84        10.73                        4.54
# 1995                         7.83        11.18                        4.53
#
# Year  Angola  Albania  Arab World  United Arab Emirates  Argentina  Armenia  \
# 1991    4.21    10.31       11.62                  1.87       5.44      1.6
# 1992    4.21    30.01       12.12                  1.84       6.36      1.8
# 1993    4.23    25.26       12.86                  1.85      10.10      5.3
# 1994    4.16    20.84       12.95                  1.81      11.76      6.6
# 1995    4.11    14.61       13.32                  1.80      18.80      6.7
#
# ...

# %%
data.isna().sum()
# Out:
# Year
# Africa Eastern and Southern    0
# Afghanistan                    0
# Africa Western and Central     0
# Angola                         0
# Albania                        0
#                               ..
# Samoa                          0
# Yemen, Rep.                    0
# South Africa                   0
# Zambia                         0
# Zimbabwe                       0
# Length: 235, dtype: int64

# %%
data.min()
# Out:
# Year
# Africa Eastern and Southern     6.27
# Afghanistan                    10.65
# Africa Western and Central      4.41
# Angola                          3.78
# Albania                        10.31
#                                ...
# Samoa                           2.10
# Yemen, Rep.                     8.31
# South Africa                   22.41
# Zambia                          7.85
# Zimbabwe                        4.39
# Length: 235, dtype: float64

# %%
data.min().min()
# Out:
# 0.1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 1991 to 2021
# Columns: 235 entries, Africa Eastern and Southern to Zimbabwe
# dtypes: float64(235)
# memory usage: 57.2+ KB

# %%
data['China'].plot(figsize=(13,5))
# Out:
# <Axes: >

# %%
data.describe()
# Out:
# Year   Africa Eastern and Southern  Afghanistan  Africa Western and Central  \
# count                    31.000000    31.000000                   31.000000
# mean                      7.244194    11.141290                    4.944194
# std                       0.609824     0.461972                    0.674694
# min                       6.270000    10.650000                    4.410000
# 25%                       6.720000    10.815000                    4.560000
# 50%                       7.310000    11.140000                    4.650000
# 75%                       7.820000    11.220000                    4.865000
# max                       8.110000    13.280000                    6.840000
#
# Year      Angola    Albania  Arab World  United Arab Emirates  Argentina  \
# count  31.000000  31.000000   31.000000             31.000000  31.000000
# mean    5.452258  16.318065   11.344516              2.345806  10.977742
# ...

# %%
data.plot(kind='box',
        subplots=True, layout=(16,16), sharex=False, sharey=False, figsize=(25,25))
plt.show()

# %%
df=data.select_dtypes(include=['number']).copy()
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
outliers_count = ((df > Q3 + 1.5 * IQR) | (df < Q1 - 1.5 * IQR)).sum()
for col in df.columns:
    print(f"Variable : {col}")
    print(f"Q1 : {Q1[col]}")
    print(f"Q3 : {Q3[col]}")
    print(f"IQR : {IQR[col]}")
    print(f"Nombre de valeurs extrêmes : {outliers_count[col]}")
    print("---------------------------")

# affichage sous forme de tableau
outliers_df = pd.DataFrame({'Variable': outliers_count.index, 'Nombre de valeurs extrêmes': outliers_count.values})
print(outliers_df)
# Out:
# Variable : Africa Eastern and Southern
# Q1 : 6.720000000000001
# Q3 : 7.82
# IQR : 1.0999999999999996
# Nombre de valeurs extrêmes : 0
# ---------------------------
# Variable : Afghanistan
# Q1 : 10.815000000000001
# Q3 : 11.22
# IQR : 0.40499999999999936
# Nombre de valeurs extrêmes : 1
# ---------------------------
# Variable : Africa Western and Central
# Q1 : 4.5600000000000005
# Q3 : 4.865
# IQR : 0.3049999999999997
# Nombre de valeurs extrêmes : 6
# ---------------------------
# Variable : Angola
# Q1 : 3.98
# Q3 : 7.38
# IQR : 3.4
# Nombre de valeurs extrêmes : 0
# ---------------------------
# Variable : Albania
# Q1 : 13.55
# Q3 : 17.975
# IQR : 4.425000000000001
# Nombre de valeurs extrêmes : 2
# ---------------------------
# Variable : Arab World
# Q1 : 10.58
# Q3 : 12.25
# IQR : 1.67
# Nombre de valeurs extrêmes : 0
# ---------------------------
# Variable : United Arab Emirates
# Q1 : 1.9049999999999998
# Q3 : 2.71
# IQR : 0.8050000000000002
# ...

# %%
data.shape
# Out:
# (31, 235)

# %%
data.corr()
# Out:
# Year                         Africa Eastern and Southern  Afghanistan  \
# Year
# Africa Eastern and Southern                     1.000000    -0.036214
# Afghanistan                                    -0.036214     1.000000
# Africa Western and Central                      0.038746     0.650875
# Angola                                         -0.416393     0.526125
# Albania                                         0.382821    -0.425438
# ...                                                  ...          ...
# Samoa                                          -0.579341     0.618546
# Yemen, Rep.                                    -0.677963     0.511123
# South Africa                                    0.923155     0.106211
# Zambia                                          0.745824    -0.265023
# Zimbabwe                                        0.455864    -0.173165
#
# Year                         Africa Western and Central    Angola   Albania  \
# Year
# ...

# %%
data.tail()
# Out:
# Year  Africa Eastern and Southern  Afghanistan  Africa Western and Central  \
# 2017                         6.71        11.18                        6.02
# 2018                         6.73        11.15                        6.04
# 2019                         6.91        11.22                        6.06
# 2020                         7.56        11.71                        6.77
# 2021                         8.11        13.28                        6.84
#
# Year  Angola  Albania  Arab World  United Arab Emirates  Argentina  Armenia  \
# 2017    7.41    13.62       10.90                  2.46       8.35    17.70
# 2018    7.42    12.30       10.50                  2.35       9.22    18.97
# 2019    7.42    11.47       10.01                  2.23       9.84    18.30
# 2020    8.33    13.33       11.49                  3.19      11.46    21.21
# 2021    8.53    11.82       11.63                  3.36      10.90    20.90
#
# ...

# %%
data.index
# Out:
# Index(['1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
data_2020 = filtered_data = data[data.index == '2020']
data_2020
# Out:
# Year  Africa Eastern and Southern  Afghanistan  Africa Western and Central  \
# 2020                         7.56        11.71                        6.77
#
# Year  Angola  Albania  Arab World  United Arab Emirates  Argentina  Armenia  \
# 2020    8.33    13.33       11.49                  3.19      11.46    21.21
#
# Year  Australia  ...  Venezuela, RB  Virgin Islands (U.S.)  Vietnam  Vanuatu  \
# 2020       6.46  ...           6.63                  13.55     2.39     2.12
#
# Year  World  Samoa  Yemen, Rep.  South Africa  Zambia  Zimbabwe
# 2020   6.57   9.15        13.39         29.22   12.85      5.35
#
# [1 rows x 235 columns]
